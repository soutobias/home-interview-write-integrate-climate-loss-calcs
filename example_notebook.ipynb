# %%
from loss_calc import exercise1_losses_calculator as normal, exercise1_losses_calculator_dask as optimized, generate_data
import cProfile
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Generate Data

# %%
# generate_data.generate_json(1_000_000, output_filename='generated_data.json')

# %% [markdown]
# # Load data and calculate processing time

# %%
# %%time
data = optimized.load_data('generated_data.json')
# Out:
# CPU times: user 2.58 s, sys: 448 ms, total: 3.03 s
# Wall time: 3.03 s

# %%
# %%time
loss = optimized.calculate_projected_losses(data)
loss
# Out:
# CPU times: user 607 ms, sys: 180 ms, total: 787 ms
# Wall time: 575 ms
# 131204244067.67334

# %%
# %%time
complex_loss = optimized.calculate_complex_projected_losses(data)
complex_loss['total']
# Out:
# CPU times: user 598 ms, sys: 82 ms, total: 680 ms
# Wall time: 542 ms
# 299180871.5913625

# %% [markdown]
# ### cProfile

# %%
# cProfile.run("optimized.calculate_complex_projected_losses(data)")
# Out:
#          25826 function calls (24104 primitive calls) in 0.240 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.015    0.015    0.240    0.240 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:12(__getattr__)
#         3    0.000    0.000    0.000    0.000 __init__.py:129(_ufunc_reduce)
#         3    0.000    0.000    0.000    0.000 __init__.py:143(__getattr__)
#        21    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         3    0.000    0.000    0.000    0.000 __init__.py:346(__getattr__)
#         3    0.000    0.000    0.000    0.000 __init__.py:40(__getattr__)
#         9    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         3    0.000    0.000    0.000    0.000 __init__.py:62(__getattr__)
# ...
